# %%
with open('resultado_part-00000', 'r') as f:
    lines = f.readlines()

# %%
file_len = len(lines)

# %%
new_list = []
for x in range(12179):
    oi = lines[x].replace('(', '').replace(')', '').replace('\n', '').split(',')
    new_list.append(oi)

# %%
del new_list[7]
sorted(new_list, key=lambda x: x[1], reverse=True)
# Out:
# [["'you", "”'", ' 6'],
#  ["'Victor", "”'", ' 4'],
#  ["'Frankenstein", "”'", ' 3'],
#  ["'cousin", "”'", ' 3'],
#  ["'know", "”'", ' 2'],
#  ["'girl", "”'", ' 2'],
#  ["'swear", "”'", ' 2'],
#  ["'father", "”'", ' 2'],
#  ["'snow", "”'", ' 1'],
#  ["'vessel", "”'", ' 1'],
#  ["'feeling", "”'", ' 1'],
#  ["'children", "”'", ' 1'],
#  ["'faces", "”'", ' 1'],
#  ["'minute", "”'", ' 1'],
#  ["'science", "”'", ' 1'],
#  ["'happy", "”'", ' 1'],
#  ["'believe", "”'", ' 1'],
#  ["'me", "”'", ' 1'],
#  ["'Clerval", "”'", ' 1'],
#  ["'yourself", "”'", ' 1'],
#  ["'ay", "”'", ' 1'],
#  ["'friend", "”'", ' 1'],
#  ["'nature", "”'", ' 1'],
#  ["'all", "”'", ' 1'],
#  ["'mean", "”'", ' 1'],
#  ["'unfortunately", "”'", ' 1'],
#  ["'Elizabeth", "”'", ' 1'],
#  ["'niece", "”'", ' 1'],
#  ["'knows", "”'", ' 1'],
#  ["'am", "”'", ' 1'],
#  ["'evidence", "”'", ' 1'],
#  ["'“Yes", "”'", ' 1'],
#  ["'die", "”'", ' 1'],
#  ["'Justine", "”'", ' 1'],
#  ["'wish", "”'", ' 1'],
#  ["'“Devil", "”'", ' 1'],
# ...

# %%
with open('resultado.txt', 'w') as w:
    for line in range(10):
        w.write(new_list[line][0])
        w.write('\n')

# %%
print(new_list[7])
# Out:
# ["'in'", ' 1129']
